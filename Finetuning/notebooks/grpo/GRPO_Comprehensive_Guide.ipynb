# %% [markdown]
# <div data-notebook-cell-style-version="2026-04-v2" style="color:#d7e0e7;line-height:1.8;font-family:ui-sans-serif,system-ui,-apple-system,BlinkMacSystemFont,'Segoe UI',sans-serif;">
# <h1 style="background:linear-gradient(135deg,#22313d 0%,#284740 100%);color:#edf5f3;padding:18px 22px;border-radius:20px;border:1px solid #3a5255;border-left:10px solid #78b0a1;box-shadow:0 10px 24px rgba(0,0,0,0.20);margin:0 0 18px 0;">Comprehensive GRPO (Group Relative Policy Optimization) Guide</h1>
# <p style="margin:10px 0 15px 0;line-height:1.82;color:#d7e0e7;font-size:1rem;">This notebook provides a comprehensive guide to GRPO training using LLaMA-Factory, covering:</p>
# <ol style="margin:10px 0 16px 20px;padding-left:18px;line-height:1.9;color:#d2dce4;">
# <li style="margin:6px 0;"><strong>GRPO Fundamentals</strong>: Understanding the GRPO algorithm</li>
# <li style="margin:6px 0;"><strong>Group-based Optimization</strong>: Efficient batch processing</li>
# <li style="margin:6px 0;"><strong>Reward Modeling</strong>: Training reward models for GRPO</li>
# <li style="margin:6px 0;"><strong>GRPO Training</strong>: Configuration and implementation</li>
# <li style="margin:6px 0;"><strong>Policy Optimization</strong>: GRPO algorithm and hyperparameters</li>
# <li style="margin:6px 0;"><strong>Evaluation</strong>: GRPO model assessment</li>
# <li style="margin:6px 0;"><strong>Advanced Techniques</strong>: Multi-reward GRPO and scaling</li>
# <li style="margin:6px 0;"><strong>Best Practices</strong>: Optimization strategies</li>
# </ol>
# <h2 style="background:linear-gradient(90deg,#22313d 0%,#273743 100%);border-left:8px solid #72aa9b;color:#e7eff3;padding:11px 16px;border-radius:14px;border:1px solid #3a4b58;box-shadow:0 6px 18px rgba(0,0,0,0.18);margin:22px 0 14px 0;">Table of Contents</h2>
# <ul style="margin:10px 0 16px 20px;padding-left:18px;line-height:1.9;color:#d2dce4;">
# <li style="margin:6px 0;"><a style="color:#8fd1ff;" href="#setup-and-installation">Setup and Installation</a></li>
# <li style="margin:6px 0;"><a style="color:#8fd1ff;" href="#grpo-fundamentals">GRPO Fundamentals</a></li>
# <li style="margin:6px 0;"><a style="color:#8fd1ff;" href="#reward-modeling">Reward Modeling</a></li>
# <li style="margin:6px 0;"><a style="color:#8fd1ff;" href="#grpo-training">GRPO Training</a></li>
# <li style="margin:6px 0;"><a style="color:#8fd1ff;" href="#policy-optimization">Policy Optimization</a></li>
# <li style="margin:6px 0;"><a style="color:#8fd1ff;" href="#evaluation">Evaluation</a></li>
# <li style="margin:6px 0;"><a style="color:#8fd1ff;" href="#advanced-techniques">Advanced Techniques</a></li>
# <li style="margin:6px 0;"><a style="color:#8fd1ff;" href="#best-practices">Best Practices</a></li>
# </ul>
# </div>

# %% [markdown]
# <div data-notebook-cell-style-version="2026-04-v2" style="color:#d7e0e7;line-height:1.8;font-family:ui-sans-serif,system-ui,-apple-system,BlinkMacSystemFont,'Segoe UI',sans-serif;">
# <h2 style="background:linear-gradient(90deg,#22313d 0%,#273743 100%);border-left:8px solid #72aa9b;color:#e7eff3;padding:11px 16px;border-radius:14px;border:1px solid #3a4b58;box-shadow:0 6px 18px rgba(0,0,0,0.18);margin:22px 0 14px 0;">Setup and Installation</h2>
# <p style="margin:10px 0 15px 0;line-height:1.82;color:#d7e0e7;font-size:1rem;">First, let's install the required dependencies for GRPO training.</p>
# </div>

# %%
# Install GRPO dependencies
# %pip install -r requirements.txt
# %pip install torch torchvision torchaudio --index-url https://download.pytorch.org/whl/cu118
# %pip install transformers[torch] datasets trl accelerate
# %pip install wandb matplotlib seaborn plotly
# %pip install torch-fidelity  # For GRPO monitoring

# Import required libraries
import torch
import transformers
from transformers import AutoTokenizer, AutoModelForCausalLM
from peft import PeftModel
import trl
import json
import os
import yaml
from typing import List, Dict, Any
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

# Check GPU availability
print(f"CUDA available: {torch.cuda.is_available()}")
print(f"GPU count: {torch.cuda.device_count()}")
if torch.cuda.is_available():
    print(f"GPU name: {torch.cuda.get_device_name(0)}")

# Set up plotting
plt.style.use('seaborn-v0_8')
sns.set_palette("husl")
