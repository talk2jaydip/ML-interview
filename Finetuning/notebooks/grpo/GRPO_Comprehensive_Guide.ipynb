# %% [markdown]
# # Comprehensive GRPO (Group Relative Policy Optimization) Guide
#
# This notebook provides a comprehensive guide to GRPO training using LLaMA-Factory, covering:
#
# 1. **GRPO Fundamentals**: Understanding the GRPO algorithm
# 2. **Group-based Optimization**: Efficient batch processing
# 3. **Reward Modeling**: Training reward models for GRPO
# 4. **GRPO Training**: Configuration and implementation
# 5. **Policy Optimization**: GRPO algorithm and hyperparameters
# 6. **Evaluation**: GRPO model assessment
# 7. **Advanced Techniques**: Multi-reward GRPO and scaling
# 8. **Best Practices**: Optimization strategies
#
# ## Table of Contents
#
# - [Setup and Installation](#setup-and-installation)
# - [GRPO Fundamentals](#grpo-fundamentals)
# - [Reward Modeling](#reward-modeling)
# - [GRPO Training](#grpo-training)
# - [Policy Optimization](#policy-optimization)
# - [Evaluation](#evaluation)
# - [Advanced Techniques](#advanced-techniques)
# - [Best Practices](#best-practices)

# %% [markdown]
# ## Setup and Installation
#
# First, let's install the required dependencies for GRPO training.

# %%
# Install GRPO dependencies
# %pip install -r requirements.txt
# %pip install torch torchvision torchaudio --index-url https://download.pytorch.org/whl/cu118
# %pip install transformers[torch] datasets trl accelerate
# %pip install wandb matplotlib seaborn plotly
# %pip install torch-fidelity  # For GRPO monitoring

# Import required libraries
import torch
import transformers
from transformers import AutoTokenizer, AutoModelForCausalLM
from peft import PeftModel
import trl
import json
import os
import yaml
from typing import List, Dict, Any
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

# Check GPU availability
print(f"CUDA available: {torch.cuda.is_available()}")
print(f"GPU count: {torch.cuda.device_count()}")
if torch.cuda.is_available():
    print(f"GPU name: {torch.cuda.get_device_name(0)}")

# Set up plotting
plt.style.use('seaborn-v0_8')
sns.set_palette("husl")
