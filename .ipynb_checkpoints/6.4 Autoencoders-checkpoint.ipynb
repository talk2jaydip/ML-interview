# %% [markdown]
# #  Autoencoders
#
# ## 1. What is an Autoencoder?
#
# An Autoencoder (AE) is a type of Artificial Neural Network used for `***unsupervised learning***`. Its primary goal is  to learn efficient representations (encodings) of the input data, typically for dimensionality reduction or feature learning.
#
# `***The core idea is to learn an identity function***` – that is, to output a reconstruction that is as close as possible to the original input.
#
#
#
# ## 3. Architecture
#
# An autoencoder consists of two main parts connected by a bottleneck layer:
#
# 1.  **Encoder:**
#     *   This part maps the input data `x` into the compressed latent representation `z`.
#     *   It typically consists of one or more layers (e.g., Dense layers in Keras/TensorFlow) with progressively fewer neurons.
#     *   `z = encoder(x)`
#
# 2.  **Bottleneck (Code / Latent Space):**
#     *   This is a hidden layer containing the compressed representation (`z`).
#     *   `***It has the smallest number of neurons***` in the typical "undercomplete" autoencoder, acting as the information bottleneck. The dimensionality of this layer represents the dimensionality of the compressed representation.
#
# 3.  **Decoder:**
#     *   This part attempts to reconstruct the original input data `x'` from the latent representation `z`.
#     *   It typically mirrors the encoder's architecture but in reverse, with layers progressively increasing in size.
#     *   `x' = decoder(z)`
#
# **Visual Structure:**
#
# `Input -> Encoder Layers -> Bottleneck (Latent Space z) -> Decoder Layers -> Output (Reconstruction x')`
#
# *(Where the number of neurons typically decreases through the encoder and increases through the decoder, and Input/Output layers have the same dimensionality).*
#
#
# ## 🔄 What Is a **Bottleneck Layer** in Neural Networks?
#
# A **bottleneck layer** is a layer in a neural network that has **fewer neurons (or filters)** compared to the layers before and after it.
#
# > 🧠 Its job is to **compress** information into a smaller, more compact form.
#
# You’ll usually find it in:
#
# -   **Autoencoders**
#
# -   **ResNet blocks**
#
# -   **MobileNets (depthwise separable convolutions)**
#
# -   Some **Transformer-style models**
#
# Input Layer         (784 nodes - 28x28 image)
# ↓
# Encoder Hidden 1    (256 nodes)
# ↓
# Bottleneck Layer    (16 nodes) ← compressed representation
# ↓
# Decoder Hidden 1    (256 nodes)
# ↓
# Output Layer        (784 nodes)
#
# ## 4. How Autoencoders Learn
#
# 1.  **Input:** An input sample `x` (e.g., an image, a feature vector) is fed into the network.
# 2.  **Encoding:** The encoder network maps `x` to the latent representation `z`.
# 3.  **Decoding:** The decoder network takes `z` and attempts to reconstruct the original input, producing `x'`.
# 4.  **Loss Calculation:** A `***reconstruction loss***` function measures the difference between the original input `x` and the reconstructed output `x'`. Common loss functions include:
#     *   **Mean Squared Error (MSE):** For continuous input data (like pixel intensities). Measures the average squared difference between `x` and `x'`.
#     *   **Binary Cross-Entropy:** For binary input data (e.g., black/white pixels).
# 5.  **Optimization:** Using backpropagation and an optimizer (like Adam, SGD), the network's weights (in both encoder and decoder) are adjusted to `***minimize the reconstruction loss***`.
#
# Through this process, the encoder learns to create informative compressed representations `z`, and the decoder learns to reconstruct the original data from those representations.
#
# ## 5. Why Use Autoencoders? (Applications)
#
# Autoencoders, despite their simple concept, are versatile:
#
# *   **Dimensionality Reduction:** After training, the `***encoder part can be used alone***` to transform high-dimensional data into a lower-dimensional representation (`z`). This compressed data can then be used for visualization or as input for other machine learning models (e.g., classifiers), potentially improving performance and reducing computational cost.
# *   **Feature Learning:** The latent representation `z` captures underlying features of the data learned in an unsupervised way.
# *   **Denoising:** A **Denoising Autoencoder** is trained by feeding it corrupted/noisy input data (`x_noisy`) but comparing the output `x'` to the original *clean* data (`x`). The network learns to remove noise and recover the underlying structure.
#     *   *Example:* Train on noisy images, but use clean images as the target reconstruction.
# *   **Anomaly Detection:** Train an autoencoder on 'normal' data. Anomalous data points, being different from the training distribution, will likely result in a `***high reconstruction error***` when passed through the trained autoencoder. This high error signals an anomaly.
# *   **Image Compression:** The encoder compresses the image into `z`, and the decoder reconstructs it. The quality depends on the bottleneck size and network capacity.
# *   **Foundation for Generative Models:** Variational Autoencoders (VAEs), a more advanced type, use a similar structure but learn a probability distribution in the latent space, allowing them to *generate* new data samples.
#
# ## 6. Common Types of Autoencoders
#
# Besides the basic undercomplete autoencoder described above:
#
# *   **Sparse Autoencoders:** Introduce a sparsity penalty to the loss function, encouraging only a small subset of neurons in the hidden layers to be active for any given input, even if the layer isn't a bottleneck.
# *   **Denoising Autoencoders (DAE):** Explicitly trained to reconstruct clean data from corrupted input.
# *   **Contractive Autoencoders (CAE):** Add a penalty to the loss function to make the learned representation (`z`) less sensitive (more robust) to small variations in the input.
# *   **Variational Autoencoders (VAE):** Generative models that learn a probability distribution for `z`, enabling generation of new data samples by sampling from this distribution.
#
# ### 🧬 Why Use Autoencoders?
#
# -   **Dimensionality Reduction** (like PCA but non-linear)
#
# -   **Data Denoising** (remove noise from input)
#
# -   **Anomaly Detection** (bad reconstructions = potential outliers)
#
# -   **Pretraining** (learn useful features unsupervised)
#
# -   **Image Compression or Generation** (e.g., as part of Variational Autoencoders)
#
#
#
# ### 🤖 What Is a Variational Autoencoder (VAE)?
#
# A **VAE** is a type of autoencoder that learns a **probabilistic mapping** from inputs to a **latent space**, rather than a fixed deterministic one.
#
# > 🧠 Instead of encoding each input to a single point, VAEs encode inputs to a **distribution** (usually Gaussian). Then they **sample** from that distribution during decoding.
#
# This enables them to:
# - Generate new, meaningful data (like GANs)
# - Handle uncertainty
# - Create smoother latent spaces
#
# ---
#
# ### 🧱 Structure of a VAE
#
# Just like a regular autoencoder, but with a probabilistic twist:
#
# #### 1. **Encoder (Inference Network)**
# Encodes input to a **mean** and **standard deviation** of a Gaussian distribution:
# ```math
# z ~ N(μ(x), σ²(x))
# ```
#
# #### 2. **Latent Space (z)**
# You don’t just get a compressed vector — you **sample** from the distribution defined by `μ` and `σ`.
#
# #### 3. **Decoder (Generative Network)**
# Takes the sampled `z` and tries to reconstruct the original input.
#
# ---
#
# ### ⚙️ How VAEs Learn (The Loss Function)
#
# The total loss is a **combination of two terms**:
#
# ```python
# VAE Loss = Reconstruction Loss + KL Divergence Loss
# ```
#
# #### ✅ 1. **Reconstruction Loss**
# Makes sure the output looks like the input.
# (e.g., MSE or binary cross-entropy)
#
# #### 🧠 2. **KL Divergence**
# Regularizes the latent space by making the `learned distribution close` to a standard normal distribution:
# ```math
# KL(N(μ, σ²) || N(0, 1))
# ```
#
# `This ensures the latent space is **continuous**, **smooth**, and allows **sampling**.`
#
# ---
#
# ### 📌 Why Use VAEs?
#
# - **Generative Modeling**
#   VAEs can create **new data samples** by sampling from the latent space. Great for generating images, text, audio, etc.
#
# - **Representation Learning**
#   Learn compact, meaningful representations of data.
#
# - **Interpolation**
#   Since the latent space is smooth, interpolating between two points creates valid, meaningful intermediate samples.
#
# ---
#
# ### 🖼️ Example: MNIST with VAEs
#
# Feed in a digit image (e.g., a "3"):
# - Encoder learns μ and σ
# - Sample z from N(μ, σ²)
# - Decoder reconstructs the digit
# - Now you can also generate new digits by sampling random z ~ N(0, 1) and decoding
#
# ---
#
# ### 💡 VAE vs. Regular Autoencoder
#
# | Feature | Autoencoder | VAE |
# |--------|-------------|-----|
# | Latent Output | Fixed vector | Distribution (mean & std) |
# | Sampling | No | Yes |
# | Generative | Limited | Yes! |
# | Loss | Just reconstruction | Reconstruction + KL Divergence |
# | Latent Space | Disorganized | Continuous, smooth |
