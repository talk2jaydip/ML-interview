# %% [markdown]
# ### RAG Embedding
# - https://github.com/run-llama/finetune-embedding/blob/main/generate_dataset.ipynb

# %% [markdown]
# ### ALL Finetuing
# - https://huggingface.co/docs/trl/main/en/community_tutorials
# - https://github.com/philschmid/deep-learning-pytorch-huggingface/tree/main
# - - https://archive.is/1gnIc

# %% [markdown]
# #### Multi gpu training
# - https://huggingface.co/docs/transformers/gpu_selection
# - https://archive.is/WRg2M#selection-8347.2-8347.33
# - https://github.com/minyang-chen/distributed_train_finetune/tree/main/deepspeed
# - https://medium.com/@daneallist/how-to-train-a-model-using-multiple-gpus-in-pytorch-cdd08c54648d

# %% [markdown]
# - https://towardsdatascience.com/to-mask-or-not-to-mask-the-effect-of-prompt-tokens-on-instruction-tuning-016f85fd67f4/
# - https://github.com/davidsvaughn/prompt-loss-weight
# - https://wandb.ai/capecape/alpaca_ft/reports/How-to-Fine-tune-an-LLM-Part-3-The-HuggingFace-Trainer--Vmlldzo1OTEyNjMy#instruction-fine-tuning-using-the-trl-library-

# %% [markdown]
# - https://github.com/NielsRogge/Transformers-Tutorials/tree/master

# %% [markdown]
# ##### CASUAL ai
# - https://medium.com/data-science/causal-machine-learning-for-customer-retention-a-practical-guide-with-python-6bd959b25741
