# %% [markdown]
# <div data-notebook-cell-style-version="2026-04-v2" style="color:#d7e0e7;line-height:1.8;font-family:ui-sans-serif,system-ui,-apple-system,BlinkMacSystemFont,'Segoe UI',sans-serif;">
# <h3 style="display:inline-block;color:#d8e4ea;background:#22303a;border-left:5px solid #7fa89e;padding:8px 14px;border-radius:12px;border:1px solid #3a4a52;margin:18px 0 10px 0;">RAG Embedding</h3>
# <ul style="margin:10px 0 16px 20px;padding-left:18px;line-height:1.9;color:#d2dce4;">
# <li style="margin:6px 0;">https://github.com/run-llama/finetune-embedding/blob/main/generate_dataset.ipynb</li>
# </ul>
# </div>

# %% [markdown]
# <div data-notebook-cell-style-version="2026-04-v2" style="color:#d7e0e7;line-height:1.8;font-family:ui-sans-serif,system-ui,-apple-system,BlinkMacSystemFont,'Segoe UI',sans-serif;">
# <h3 style="display:inline-block;color:#d8e4ea;background:#22303a;border-left:5px solid #7fa89e;padding:8px 14px;border-radius:12px;border:1px solid #3a4a52;margin:18px 0 10px 0;">ALL Finetuing</h3>
# <ul style="margin:10px 0 16px 20px;padding-left:18px;line-height:1.9;color:#d2dce4;">
# <li style="margin:6px 0;">https://huggingface.co/docs/trl/main/en/community_tutorials</li>
# <li style="margin:6px 0;">https://github.com/philschmid/deep-learning-pytorch-huggingface/tree/main</li>
# <li style="margin:6px 0;">
# <ul style="margin:10px 0 16px 20px;padding-left:18px;line-height:1.9;color:#d2dce4;">
# <li style="margin:6px 0;">https://archive.is/1gnIc</li>
# </ul>
# </li>
# </ul>
# </div>

# %% [markdown]
# <div data-notebook-cell-style-version="2026-04-v2" style="color:#d7e0e7;line-height:1.8;font-family:ui-sans-serif,system-ui,-apple-system,BlinkMacSystemFont,'Segoe UI',sans-serif;">
# <h4 style="color:#9fd2c3;margin:16px 0 8px 0;font-weight:700;">Multi gpu training</h4>
# <ul style="margin:10px 0 16px 20px;padding-left:18px;line-height:1.9;color:#d2dce4;">
# <li style="margin:6px 0;">https://huggingface.co/docs/transformers/gpu_selection</li>
# <li style="margin:6px 0;">https://archive.is/WRg2M#selection-8347.2-8347.33</li>
# <li style="margin:6px 0;">https://github.com/minyang-chen/distributed_train_finetune/tree/main/deepspeed</li>
# <li style="margin:6px 0;">https://medium.com/@daneallist/how-to-train-a-model-using-multiple-gpus-in-pytorch-cdd08c54648d</li>
# </ul>
# </div>

# %% [markdown]
# <div data-notebook-cell-style-version="2026-04-v2" style="color:#d7e0e7;line-height:1.8;font-family:ui-sans-serif,system-ui,-apple-system,BlinkMacSystemFont,'Segoe UI',sans-serif;">
# <ul style="margin:10px 0 16px 20px;padding-left:18px;line-height:1.9;color:#d2dce4;">
# <li style="margin:6px 0;">https://towardsdatascience.com/to-mask-or-not-to-mask-the-effect-of-prompt-tokens-on-instruction-tuning-016f85fd67f4/</li>
# <li style="margin:6px 0;">https://github.com/davidsvaughn/prompt-loss-weight</li>
# <li style="margin:6px 0;">https://wandb.ai/capecape/alpaca_ft/reports/How-to-Fine-tune-an-LLM-Part-3-The-HuggingFace-Trainer--Vmlldzo1OTEyNjMy#instruction-fine-tuning-using-the-trl-library-</li>
# </ul>
# </div>

# %% [markdown]
# <div data-notebook-cell-style-version="2026-04-v2" style="color:#d7e0e7;line-height:1.8;font-family:ui-sans-serif,system-ui,-apple-system,BlinkMacSystemFont,'Segoe UI',sans-serif;">
# <ul style="margin:10px 0 16px 20px;padding-left:18px;line-height:1.9;color:#d2dce4;">
# <li style="margin:6px 0;">https://github.com/NielsRogge/Transformers-Tutorials/tree/master</li>
# </ul>
# </div>

# %% [markdown]
# <div data-notebook-cell-style-version="2026-04-v2" style="color:#d7e0e7;line-height:1.8;font-family:ui-sans-serif,system-ui,-apple-system,BlinkMacSystemFont,'Segoe UI',sans-serif;">
# <h5>CASUAL ai</h5>
# <ul style="margin:10px 0 16px 20px;padding-left:18px;line-height:1.9;color:#d2dce4;">
# <li style="margin:6px 0;">https://medium.com/data-science/causal-machine-learning-for-customer-retention-a-practical-guide-with-python-6bd959b25741</li>
# </ul>
# </div>
