# %% [markdown]
# <div data-notebook-cell-style-version="2026-04-v2" style="color:#d7e0e7;line-height:1.8;font-family:ui-sans-serif,system-ui,-apple-system,BlinkMacSystemFont,'Segoe UI',sans-serif;">
# <ul style="margin:10px 0 16px 20px;padding-left:18px;line-height:1.9;color:#d2dce4;">
# <li style="margin:6px 0;">https://colab.research.google.com/drive/1Y2tkmSI7n-tTlkkzvc6ruv1FhX_omQ86</li>
# </ul>
# </div>

# %% [markdown]
# <div data-notebook-cell-style-version="2026-04-v2" style="color:#d7e0e7;line-height:1.8;font-family:ui-sans-serif,system-ui,-apple-system,BlinkMacSystemFont,'Segoe UI',sans-serif;">
# <ul style="margin:10px 0 16px 20px;padding-left:18px;line-height:1.9;color:#d2dce4;">
# <li style="margin:6px 0;">https://colab.research.google.com/drive/1_HQL7k1BA_C6h0mffhv9TLV7lS5aX21O?usp=sharing</li>
# <li style="margin:6px 0;">https://archive.is/FS7tV : Finetuning Embedding</li>
# </ul>
# </div>
